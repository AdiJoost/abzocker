# %% [markdown]
# # Mixture of experts, a simple example

# %% [markdown]
# Exploring the MoE architecture for CNNs

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.utils import to_categorical
import numpy as np
from keras import layers, models

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
#normalixe pixel values
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

#convert labels to one hot
num_classes = 10
y_train  = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 37s 0us/step

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Expert Model

# %% [markdown]
# Now that we have the data, we will create our expert models and our gating model separately to combine them later

# %%
def create_expert_model(input_shape, num_outputs):
    model = models.Sequential([
        layers.Conv2D(32,(3,3), activation="relu",)
    ])
